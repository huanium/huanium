# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import fft, fftfreq

# %% [markdown]
# Define density response function:
#
# $$ \chi_n(\omega, k)  = k^2 \frac{-\omega - i k^2 \gamma D_T}{(\omega^2 - c^2 k^2 + iD_s k^2 \omega)(\omega + i D_T k^2 )}$$

# %%
def chi_n_FT(w,k,c,gamma, DT, Ds):    
    return (k**2)*(-w-1j*(k**2)*gamma*DT) /( ( w**2 - (c**2)*(k**2) + 1j*Ds*(k**2)*w ) *(w+1j*DT*(k**2)) )

# %% [markdown]
# Next, define the drive:
# $$ \delta V(z,t) = \delta V_z(z) \delta V_t(t) = \exp\left( -\frac{z^2}{2 s^2} \right) \left[ \Theta\left( T_\text{shake} - t  \right)  \sin(\omega_d t) + 2\right] $$
# where $s$ is the wall sharpness

# %%
def deltaV_t(wd, shake_duration, t):
    return np.sin(wd*t)*np.heaviside(shake_duration-t, 1) + 2

def deltaV_z(z, sharpness):
    return np.exp(-z**2/(2*sharpness**2))
    #return np.cos(2*np.pi*2.0*z)

# %%
# sampling rate
sr = 2000
# shaking frequency (Hz)
shake_freq = 100 
# shaking cycles:
shake_cycles = 10
# sampling interval
ts = 1.0/sr
# shake duration:
shake_duration = shake_cycles/shake_freq

# length of box (um)
L = 100

# %%
t = np.arange(0, 3*shake_duration, ts)
wd = 2*np.pi*shake_freq
deltaV_t_values = deltaV_t(wd, shake_duration, t)

deltaV_t_values_FT = fft(deltaV_t_values)
N = len(deltaV_t_values_FT)
n = np.arange(N)
T = N/sr
freq = n/T 

plt.figure(figsize = (6, 3))
plt.subplot(121)

plt.stem(freq, np.abs(deltaV_t_values_FT), 'b', markerfmt = " ", basefmt="-k")
plt.xlabel('Freq (Hz)')
plt.ylabel('FFT Amplitude')
plt.xlim(0, 400)
plt.ylim(0, 120)

plt.subplot(122)
plt.plot(t, deltaV_t_values, 'r')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/v2/qlb19m_922j0wts1jqdyjw100000gn/T/ipykernel_58557/2128386259.py:14: MatplotlibDeprecationWarning: Passing the linefmt parameter positionally is deprecated since Matplotlib 3.5; the parameter will become keyword-only two minor releases later.
#   plt.stem(freq, np.abs(deltaV_t_values_FT), 'b', markerfmt = " ", basefmt="-k")

# %%
# box sampling rate:
sr_box = 500
# box sampling interval:
bs = 1.0/sr_box
# span of box
box = np.arange(0, L, bs)
sharpness = 3.0

deltaV_z_values = deltaV_z(box, sharpness)
deltaV_z_values_FT = fft(deltaV_z_values)
N_box = len(deltaV_z_values_FT)
n_box = np.arange(N_box)
L_box = N_box/sr
k = n_box/L_box 

plt.figure(figsize = (6, 3))
plt.subplot(121)

plt.stem(k, np.abs(deltaV_z_values_FT), 'b', markerfmt = " ", basefmt="-k")
plt.xlabel('k/$2\pi$ ($1/\mu$m)')
plt.ylabel('FFT Amplitude')
plt.xlim(0, 400)
plt.ylim(0, 120)

plt.subplot(122)
plt.plot(box, deltaV_z_values, 'r')
plt.xlabel('Position ($\mu$m)')
plt.ylabel('Amplitude')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/v2/qlb19m_922j0wts1jqdyjw100000gn/T/ipykernel_58557/3126903885.py:19: MatplotlibDeprecationWarning: Passing the linefmt parameter positionally is deprecated since Matplotlib 3.5; the parameter will become keyword-only two minor releases later.
#   plt.stem(k, np.abs(deltaV_z_values_FT), 'b', markerfmt = " ", basefmt="-k")

# %%
for j in range(len(k)):
    
    XV = chi_n_FT(2*np.pi*freq, 2*np.pi*k[j], 100000, 2, 2, 2)*deltaV_t_values_FT*deltaV_z_values_FT[j]
# Out:
# /var/folders/v2/qlb19m_922j0wts1jqdyjw100000gn/T/ipykernel_58557/2279543610.py:2: RuntimeWarning: invalid value encountered in true_divide
#   return (k**2)*(-w-1j*(k**2)*gamma*DT) /( ( w**2 - (c**2)*(k**2) + 1j*Ds*(k**2)*w ) *(w+1j*DT*(k**2)) )
